# %% [markdown]
# # Introduction to Sets in Python

# %% [markdown]
# ## 🔥 Python Sets
#
# **Sets in Python are a powerful built-in data structure designed for handling unique, unordered collections of elements.** Although beginners sometimes overlook them in favor of lists, understanding sets is essential for writing efficient, clean, and optimized Python code.
#
# This article covers everything you need to know about sets — from what they are, how they work, their internal implementation, all operations, and real-world use cases.

# %% [markdown]
# ## 🧩 What Is a Set in Python?
#
# - A set in Python is an **unordered, mutable, and unique**-collection data structure.
#
# ### ✔ Unordered
# - Items in a set do not have positions **(no indexing)**.
# - The interpreter decides the **internal order (based on hashing)**.
#
# ### ✔ Mutable
#
# - You can **add or remove items** after creating a set.
#
# ### ✔ Unique Items
#
# - A set **automatically removes duplicates**.

# %% [markdown]
# ## 🛠️ How to Create a Set
# ### 1. Using curly braces {}
# ```python
# s = {1, 2, 3}
# ```
#
# ### 2. Using the set() constructor
# ```python
# s = set([1, 2, 3])
# ```
#
# ### ❗ Creating an empty set requires set()
# ```python
# s = {}      # ❌ This creates an empty dict
# s = set()   # ✔ Correct empty set
# ```

# %% [markdown]
# ## 🧱 **What Can a Set Contain?**
#
# A set can contain **only hashable (immutable)** objects:
#
# - ✔ integers
# - ✔ floats
# - ✔ strings
# - ✔ tuples
#
# - ❌ lists
# - ❌ dictionaries
# - ❌ other sets
#
# **Why?**
# Because these are **mutable → their hash can change → breaks set integrity**.
#
# However, it can contain:
#
# - ✔ `frozenset()` (because it is immutable)
#
# Example:
#
# ```python
# s = {1, "hello", (2,3), frozenset([4,5])}
# ```
#
# ## ⚙️ **Internal Working of Sets (Important)**
#
# Sets are implemented as **hash tables**, similar to dictionaries.
#
# Each item is:
#
# * hashed using Python’s hash function
# * placed in a "bucket" based on this hash
#
# This gives sets two superpowers:
#
# ### ⭐ O(1) average lookup time
#
# Checking membership is extremely fast:
#
# ```python
# if 10 in s:
#     ...
# ```
#
# ### ⭐ Automatic duplicate removal
#
# Two equal objects have the same hash → stored once.

# %% [markdown]
# ## 🧰 Basic Set Operations

# %%
# add an item
s = set()
s.add(10)
s
# Out:
# {10}

# %%
# add multiple items 
s.update([4,5,'a'])
s
# Out:
# {10, 4, 5, 'a'}

# %%
# remove elements - throws error if element is not found in set
try:
    s.remove(10)
except Exception as e:
    print(e)
    
s
# Out:
# {4, 5, 'a'}

# %%
# Discard (safe — no error)
s.discard('a')
s
# Out:
# {4, 5}

# %%
# Pop (removes a random element)
s.pop()
s
# Out:
# {5}

# %%
# clear 
s.clear()
s
# Out:
# set()

# %% [markdown]
# ## 🔗 Set Mathematical Operations
#
# Python sets behave like mathematical sets.

# %%
a = {1,2,3}
b = {3,4,5}

# %%
# Union (| or union())
a|b
# Out:
# {1, 2, 3, 4, 5}

# %%
# Intersection (& or intersection())
a&b
# Out:
# {3}

# %%
# Difference (- or difference())
a-b
# Out:
# {1, 2}

# %%
# Symmetric Difference (^ or symmetric_difference())
a^b
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# ## ⚖️ Comparison Operations

# %%
# subset
a.issubset(b)
# Out:
# False

# %%
# superset
a.issuperset(b)
# Out:
# False

# %%
# disjoint 
a.isdisjoint(b)
# Out:
# False

# %% [markdown]
# ## 📚 Full List of Set Methods
#
# | Method                   | Purpose                      |
# | ------------------------ | ---------------------------- |
# | `add()`                  | Add an element               |
# | `update()`               | Add multiple elements        |
# | `remove()`               | Remove (error if missing)    |
# | `discard()`              | Remove (no error)            |
# | `pop()`                  | Remove random element        |
# | `clear()`                | Empty the set                |
# | `union()`                | Combine sets                 |
# | `intersection()`         | Common items                 |
# | `difference()`           | Items in A not B             |
# | `symmetric_difference()` | Items in A or B but not both |
# | `issubset()`             | Subset check                 |
# | `issuperset()`           | Superset check               |
# | `isdisjoint()`           | Check if intersection empty  |

# %% [markdown]
# ## 🧠 **Advanced Concepts**
#
# ### 1. Using Sets for Fast Membership Testing
#
# ```python
# allowed = {"png", "jpg", "jpeg"}
#
# if ext in allowed:
#     print("Valid file")
# ```
#
# This is MUCH faster than using a list.
#
# ---
#
# ### 2. Set Comprehensions
#
# ```python
# s = {x*x for x in range(5)}
# # {0, 1, 4, 9, 16}
# ```
#
# ---
#
# ### 3. Removing Duplicates from a List
#
# ```python
# nums = [1,2,2,3,3,3]
# unique = list(set(nums))
# ```
#
# ---
#
# ### 4. Finding Unique Words in Text
#
# ```python
# text = "python is great and python is easy"
# unique_words = set(text.split())
# ```
#
# ---
#
# ### 5. Comparing Two Lists Efficiently
#
# ```python
# common = set(list1) & set(list2)
# ```
#
# ---
#
# ### 6. Creating Sets of Sets Using `frozenset`
#
# ```python
# s = {frozenset([1,2]), frozenset([3,4])}
# ```
#
#
# ## ⚠️ **Common Mistakes with Sets**
#
# ### 1. Trying to index a set
#
# ```python
# s = {1,2,3}
# s[0]   # ❌ Error — sets have no order
# ```
#
# ### 2. Using mutable items in a set
#
# ```python
# s = { [1,2] }  # ❌ Error: unhashable type: 'list'
# ```
#
# ### 3. Expecting a consistent order
#
# ```python
# print({1,2,3})
# # may print {1,3,2}
# ```
#
#
# ## 🆚 **Set vs List vs Tuple**
#
# | Feature           | List  | Tuple | Set   |
# | ----------------- | ----- | ----- | ----- |
# | Ordered           | ✔ Yes | ✔ Yes | ❌ No  |
# | Mutable           | ✔ Yes | ❌ No  | ✔ Yes |
# | Allows duplicates | ✔ Yes | ✔ Yes | ❌ No  |
# | Fast lookup       | ❌ No  | ❌ No  | ✔ Yes |
# | Hashable          | ❌ No  | ✔ Yes | ❌ No  |
#
#
# ## 🌍 **Real-world Use Cases of Sets**
#
# ### 🔹 1. Removing duplicates from large datasets
#
# ### 🔹 2. Membership checks (e.g., valid tokens, whitelists)
#
# ### 🔹 3. Graph algorithms (neighbors, visited nodes)
#
# ### 🔹 4. Comparing user permissions
#
# ### 🔹 5. Deduping rows in ETL pipelines
#
# ### 🔹 6. NLP (unique vocabulary extraction)
#
# ### 🔹 7. Parsing logs for unique IP addresses
#
# ### 🔹 8. Detecting overlaps in schedules, time slots
#
#
# # 📝 **Summary**
#
# Python sets are:
#
# * **unordered**
# * **mutable**
# * **duplicate-free**
# * **hash-table based**
# * **fast for membership checks**
# * **powerful for mathematical set operations**
#
# They are ideal whenever:
#
# * You need uniqueness
# * You need fast lookup
# * Order doesn’t matter
#
# Understanding sets (and their immutable sibling `frozenset`) is crucial for writing efficient and Pythonic code.

# %% [markdown]
# ---
