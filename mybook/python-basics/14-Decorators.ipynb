# %% [markdown]
# # Introduction to Decorators in Python

# %% [markdown]
# ## 🎯 What Is a Decorator?
#
# A **decorator** is a function that modifies the behavior of another function or class, without permanently changing its code.
#
# It’s a **higher-order function**, meaning:
# > It either takes another function as input or returns another function as output.
#
# ## Simple Analogy 💡
#
# Think of a decorator like a gift wrapper 🎁.
# - The **gift** = your function
# - The **wrapper** = decorator
#
# You still get the gift, but now it’s enhanced — maybe labeled, logged, or authenticated.

# %% [markdown]
# ---

# %% [markdown]
# ## ⚙️ Functions Are First-Class Citizens in Python
#
# Before decorators, you must understand one key concept:
#
# ✅ Functions can be:
# - Assigned to variables
# - Passed as arguments
# - Returned from other functions

# %%
# example 
def greet(name):
    return f"Hello, {name}"

say_hello = greet   # assign function
print(say_hello("Binayak"))  # Hello, Binayak
# Out:
# Hello, Binayak

# %% [markdown]
# ---

# %% [markdown]
# ## 🧩 Higher-Order Functions
#
# A higher-order function is one that:
# - Takes another function as an argument, OR
# - Returns a function.

# %%
def shout(text):
    return text.upper()

# Here, greet() takes another function shout as an argument.
def greet(func):
    result = func("hello")
    print(result)

greet(shout)
# Out:
# HELLO

# %% [markdown]
# ---

# %% [markdown]
# ## 🪄 Creating a Simple Decorator (Step-by-Step)
#
# Let’s build our first decorator manually.

# %% [markdown]
# ### Step 1: Write a normal function

# %%
def say_hello():
    print("Hello!")

# %% [markdown]
# ### Step 2: Write a decorator function

# %%
def decorator(func):
    def wrapper():
        print("Before function runs")
        func()
        print("After function runs")
    return wrapper

# %% [markdown]
# ### Step 3: Apply decorator manually

# %%
say_hello = decorator(say_hello)
say_hello()
# Out:
# Before function runs
# Hello!
# After function runs

# %% [markdown]
# ✅ What happened?
# - `decorator(say_hello)` returns the `wrapper` function.
#
# So now `say_hello` points to `wrapper`, not the original `say_hello`.

# %% [markdown]
# ---

# %% [markdown]
# ## 🧠 5. Using the @ Syntax (Syntactic Sugar)
#
# Python provides a cleaner way to apply decorators using `@`.
#
# Instead of:
#
# ```
# say_hello = decorator(say_hello)
# ```

# %%
@decorator
def say_hello():
    print("Hello!")

# %%
say_hello()
# Out:
# Before function runs
# Hello!
# After function runs

# %% [markdown]
# Now every time `say_hello()` is called, it runs inside `wrapper()`.

# %% [markdown]
# ---

# %% [markdown]
# ## 🧰 6. Decorator with Function Arguments
#
# If the function you decorate takes arguments, your wrapper should too.

# %%
def decorator(func):
    def wrapper(*args, **kwargs):
        print("Namaste!")
        func(*args, **kwargs)
        print("Enjoy the Party!")
    return wrapper 


@decorator
def greet(name):
    print(f"Hello! {name}")

# %%
greet("Binayak")
# Out:
# Namaste!
# Hello! Binayak
# Enjoy the Party!

# %% [markdown]
# ---

# %% [markdown]
# ## 🧮 Returning Values from Decorated Functions
#
# If the function returns something, wrapper should return it too.

# %%
def decorator(func):
    def wrapper(*args, **kwargs):
        print("Before call")
        result = func(*args, **kwargs)
        print("After call")
        return result 
    return wrapper 

@decorator
def add(a,b):
    return a+b

add(3,4)
# Out:
# Before call
# After call
# 7

# %% [markdown]
# ### 💡 Code Recap
#
# ```python
# def decorator(func):
#     def wrapper(*args, **kwargs):
#         print("Before call")
#         result = func(*args, **kwargs)
#         print("After call")
#         return result
#     return wrapper
#
# @decorator
# def add(a,b):
#     return a+b
#
# add(3,4)
# ```
#
# ### 🧠 Step-by-Step Execution
#
# 1. **Decorator definition**
#
#    The function `decorator` is defined.
#    It accepts another function (`func`) and returns the nested `wrapper` function.
#
#
# 2. **Decorator application (`@decorator`)**
#
#    When you write:
#
#    ```python
#    @decorator
#    def add(a, b):
#        return a + b
#    ```
#
#    it’s **equivalent to**:
#
#    ```python
#    def add(a, b):
#        return a + b
#
#    add = decorator(add)
#    ```
#
#    So now, `add` **no longer points to the original `add` function**.
#    Instead, it points to the **`wrapper` function returned by `decorator`**.
#
#
# 3. **Calling `add(3, 4)`**
#
#    When you run:
#
#    ```python
#    add(3, 4)
#    ```
#
#    it actually calls `wrapper(3, 4)`.
#
#    Inside `wrapper`:
#
#    * First: `print("Before call")` → ✅ prints
#
#      ```
#      Before call
#      ```
#
#    * Then: `result = func(*args, **kwargs)`
#      Here, `func` refers to the **original `add` function**,
#      so `func(3, 4)` returns `7`.
#      That value is stored in `result`.
#
#    * Next: `print("After call")` → ✅ prints
#
#      ```
#      After call
#      ```
#
#    * Finally: `return result` → returns `7`.
#
#
# ### 🖨️ Output on the Screen
#
# So the sequence of events and prints is:
#
# ```
# Before call
# After call
# ```
#
# Then the returned value `7` is printed by the interpreter **only because you ran this code in an interactive environment (like IDLE, Jupyter, or REPL)** — where the last expression’s result is **automatically displayed**.
#
#
# ### ✅ Final Explanation
#
# * `"Before call"` → printed from the decorator.
# * `"After call"` → printed from the decorator.
# * `7` → **returned** from the function and **automatically printed** by your interactive environment (not explicitly printed by your code).
#
#
# ### 📋 If you run it in a script (like `python file.py`)
#
# You’d only see:
#
# ```
# Before call
# After call
# ```
#
# Because the return value `7` isn’t printed — it’s just returned.
#
#
# ### ✅ To see the result explicitly:
#
# You’d write:
#
# ```python
# result = add(3, 4)
# print(result)
# ```
#
# Output:
#
# ```
# Before call
# After call
# 7
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 🧩 Real-World Example — Logging Decorator

# %%
def log(func):
    def wrapper(*args, **kwargs):
        print(f"Calling {func.__name__} with {args} {kwargs}")
        result = func(*args, **kwargs)
        print(f"{func.__name__} returned {result}")
        return result
    return wrapper

@log
def multiply(x, y):
    return x * y

multiply(3, 4)
# Out:
# Calling multiply with (3, 4) {}
# multiply returned 12
# 12

# %% [markdown]
# ---

# %% [markdown]
# ## 🧠 Stacking Multiple Decorators
#
# You can apply more than one decorator — they run from bottom to top.

# %%
def star(func):
    def wrapper(*args, **kwargs):
        print("⭐" * 10)
        func(*args, **kwargs)
        print("⭐" * 10)
    return wrapper

def hash(func):
    def wrapper(*args, **kwargs):
        print("#" * 10)
        func(*args, **kwargs)
        print("#" * 10)
    return wrapper

@star
@hash
def greet(name):
    print(f"Hello, {name}")
    
greet("Binayak")
# Out:
# ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐
# ##########
# Hello, Binayak
# ##########
# ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐

# %% [markdown]
# ---

# %% [markdown]
# ## 🧩 Decorators with Parameters
#
# If you want to pass arguments to a decorator itself (not to the function it wraps), you add another layer.

# %%
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

@repeat(3)
def say_hi():
    print("Hi!")

say_hi()
# Out:
# Hi!
# Hi!
# Hi!

# %% [markdown]
# ---

# %% [markdown]
# ## 🧱 Preserving Function Metadata (functools.wraps)
#
# After decoration, the function loses its metadata like name and docstring.

# %%
def decorator(func):
    def wrapper():
        print("Wrapped!")
        func()
    return wrapper

@decorator
def hello():
    """This greets."""
    print("Hello")

print(hello.__name__)  # wrapper ❌
print(hello.__doc__)   # None ❌
# Out:
# wrapper
# None

# %% [markdown]
# To fix this:

# %%
from functools import wraps 

def decorator(func):
    @wraps(func)
    def wrapper():
        print("Wrapped!")
        func()
    return wrapper


@decorator
def hello():
    """This greets."""
    print("Hello")

print(hello.__name__) 
print(hello.__doc__)
# Out:
# hello
# This greets.

# %% [markdown]
# ---

# %% [markdown]
# ## ⚡ Common Real-World Uses of Decorators
#
# | Use Case                  | Description                                                       |
# | ------------------------- | ----------------------------------------------------------------- |
# | **Logging**               | Track function calls                                              |
# | **Authentication**        | Restrict access to certain routes (e.g., Flask `@login_required`) |
# | **Caching**               | Store results to speed up repeated calls (`@lru_cache`)           |
# | **Validation**            | Check arguments before running a function                         |
# | **Timing**                | Measure execution time of a function                              |
# | **Flask / Django Routes** | Map URLs to functions (`@app.route('/home')`)                     |

# %% [markdown]
# ---
